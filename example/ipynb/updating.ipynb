# %% [markdown]
# # Updating your software
#
# If you want to test a specific MyHDL branch, you can either install it over the default or provide a different path.
# Here are your options.
#
# ## Pulling a specific branch
#
# To checkout the most recent jupyosys branch of MyHDL:

# %%
! git pull
! git checkout jupyosys

# %% [markdown]
# Install over the old one:

# %%
! cd ../../ && python3 setup.py install --user
# Out:
# running install
# running bdist_egg
# running egg_info
# writing myhdl.egg-info/PKG-INFO
# writing dependency_links to myhdl.egg-info/dependency_links.txt
# writing top-level names to myhdl.egg-info/top_level.txt
# reading manifest file 'myhdl.egg-info/SOURCES.txt'
# reading manifest template 'MANIFEST.in'
# warning: no files found matching 'makefile*' anywhere in distribution
# no previously-included directories found matching '.hg'
# no previously-included directories found matching 'dist'
# no previously-included directories found matching 'olddoc'
# no previously-included directories found matching 'myhdl/old_conversion'
# no previously-included directories found matching 'myhdl/*/work'
# no previously-included directories found matching 'myhdl/*/*/work'
# no previously-included directories found matching 'myhdl/*/*/*/work'
# no previously-included directories found matching 'myhdl/*/work_vlog'
# no previously-included directories found matching 'myhdl/*/*/work_vlog'
# no previously-included directories found matching 'myhdl/*/*/*/work_vlog'
# no previously-included directories found matching 'myhdl/*/work_vcom'
# no previously-included directories found matching 'myhdl/*/*/work_vcom'
# no previously-included directories found matching 'myhdl/*/*/*/work_vcom'
# warning: no directories found matching 'doc/build/html'
# writing manifest file 'myhdl.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# copying myhdl/_misc.py -> build/lib/myhdl
# copying myhdl/_Signal.py -> build/lib/myhdl
# copying myhdl/_Cosimulation.py -> build/lib/myhdl
# copying myhdl/_always.py -> build/lib/myhdl
# copying myhdl/_blackbox.py -> build/lib/myhdl
# copying myhdl/_Simulation.py -> build/lib/myhdl
# copying myhdl/_block.py -> build/lib/myhdl
# copying myhdl/_bulksignal.py -> build/lib/myhdl
# copying myhdl/_always_seq.py -> build/lib/myhdl
# copying myhdl/__init__.py -> build/lib/myhdl
# copying myhdl/conversion/_toYosys.py -> build/lib/myhdl/conversion
# copying myhdl/conversion/yosys_bb.py -> build/lib/myhdl/conversion
# copying myhdl/conversion/synmapper.py -> build/lib/myhdl/conversion
# copying myhdl/conversion/yshelper.py -> build/lib/myhdl/conversion
# copying myhdl/conversion/analyze_ng.py -> build/lib/myhdl/conversion
# copying myhdl/conversion/ysmodule_ng.py -> build/lib/myhdl/conversion
# copying myhdl/conversion/ysdebug.py -> build/lib/myhdl/conversion
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/myhdl
# creating build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_analyze.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_VHDLNameValidation.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_misc.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/auxiliaries.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_toVHDLPackage.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_toYosys.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/yshelper_dummy.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/ysmodule.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_verify.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/yosys_bb.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/synmapper.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/blackbox.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/yshelper.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/syn.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_toVHDL.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/analyze_ng.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_toVerilog.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/ecp5.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/ysmodule_ng.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/annotate.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/_yshelper.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/ysdebug.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/conversion/__init__.py -> build/bdist.linux-x86_64/egg/myhdl/conversion
# copying build/lib/myhdl/_modbv.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_enum.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_ShadowSignal.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_misc.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_instance.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_Signal.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_Cosimulation.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_tristate.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_traceSignals.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_always.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_util.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_blackbox.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_intbv.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_Simulation.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_block.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_extractHierarchy.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_compat.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_getHierarchy.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_bin.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_getcellvars.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/debug.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_Waiter.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_always_comb.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_bulksignal.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_visitors.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_join.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_simulator.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_resolverefs.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_delay.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_always_seq.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/_concat.py -> build/bdist.linux-x86_64/egg/myhdl
# copying build/lib/myhdl/__init__.py -> build/bdist.linux-x86_64/egg/myhdl
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_analyze.py to _analyze.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_VHDLNameValidation.py to _VHDLNameValidation.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_misc.py to _misc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/auxiliaries.py to auxiliaries.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_toVHDLPackage.py to _toVHDLPackage.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_toYosys.py to _toYosys.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/yshelper_dummy.py to yshelper_dummy.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/ysmodule.py to ysmodule.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_verify.py to _verify.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/yosys_bb.py to yosys_bb.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/synmapper.py to synmapper.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/blackbox.py to blackbox.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/yshelper.py to yshelper.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/syn.py to syn.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_toVHDL.py to _toVHDL.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/analyze_ng.py to analyze_ng.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_toVerilog.py to _toVerilog.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/ecp5.py to ecp5.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/ysmodule_ng.py to ysmodule_ng.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/annotate.py to annotate.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/_yshelper.py to _yshelper.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/ysdebug.py to ysdebug.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/conversion/__init__.py to __init__.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_modbv.py to _modbv.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_enum.py to _enum.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_ShadowSignal.py to _ShadowSignal.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_misc.py to _misc.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_instance.py to _instance.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_Signal.py to _Signal.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_Cosimulation.py to _Cosimulation.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_tristate.py to _tristate.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_traceSignals.py to _traceSignals.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_always.py to _always.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_util.py to _util.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_blackbox.py to _blackbox.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_intbv.py to _intbv.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_Simulation.py to _Simulation.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_block.py to _block.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_extractHierarchy.py to _extractHierarchy.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_compat.py to _compat.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_getHierarchy.py to _getHierarchy.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_bin.py to _bin.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_getcellvars.py to _getcellvars.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/debug.py to debug.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_Waiter.py to _Waiter.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_always_comb.py to _always_comb.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_bulksignal.py to _bulksignal.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_visitors.py to _visitors.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_join.py to _join.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_simulator.py to _simulator.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_resolverefs.py to _resolverefs.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_delay.py to _delay.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_always_seq.py to _always_seq.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/_concat.py to _concat.cpython-37.pyc
# byte-compiling build/bdist.linux-x86_64/egg/myhdl/__init__.py to __init__.cpython-37.pyc
# installing package data to build/bdist.linux-x86_64/egg
# running install_data
# creating build/bdist.linux-x86_64/egg/share
# creating build/bdist.linux-x86_64/egg/share/myhdl
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/test_bin2gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/bin2gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/test_all.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/test_dff.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/inc.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/test_inc.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/dff_clkout.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# copying cosimulation/test/dff.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/dff_clkout.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/dut_dff.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/dut_bin2gray.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/dut_inc.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/inc.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/dff.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/bin2gray.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# copying cosimulation/test/verilog/dut_dff_clkout.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/test/verilog
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win
# copying cosimulation/modelsim-win/myhdl_vpi.c -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win
# copying cosimulation/modelsim-win/Makefile -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win/test
# copying cosimulation/modelsim-win/test/bin2gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win/test
# copying cosimulation/modelsim-win/test/test_all.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win/test
# copying cosimulation/modelsim-win/test/inc.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win/test
# copying cosimulation/modelsim-win/test/dff_clkout.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win/test
# copying cosimulation/modelsim-win/test/dff.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim-win/test
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver
# copying cosimulation/cver/myhdl_vpi.c -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver
# copying cosimulation/cver/Makefile.osx -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver
# copying cosimulation/cver/Makefile.lnx64 -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver
# copying cosimulation/cver/Makefile.lnx -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver
# copying cosimulation/cver/README.txt -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver/test
# copying cosimulation/cver/test/bin2gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver/test
# copying cosimulation/cver/test/test_all.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver/test
# copying cosimulation/cver/test/inc.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver/test
# copying cosimulation/cver/test/dff_clkout.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver/test
# copying cosimulation/cver/test/dff.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/cver/test
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim
# copying cosimulation/modelsim/myhdl_vpi.c -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim
# copying cosimulation/modelsim/Makefile -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim/test
# copying cosimulation/modelsim/test/bin2gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim/test
# copying cosimulation/modelsim/test/test_all.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim/test
# copying cosimulation/modelsim/test/inc.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim/test
# copying cosimulation/modelsim/test/dff_clkout.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim/test
# copying cosimulation/modelsim/test/dff.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/modelsim/test
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus
# copying cosimulation/icarus/myhdl_table.c -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus
# copying cosimulation/icarus/myhdl_20030518.c -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus
# copying cosimulation/icarus/myhdl.c -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus
# copying cosimulation/icarus/Makefile -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus
# copying cosimulation/icarus/README.txt -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus
# creating build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/bin2gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/test_all.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/inc.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/test.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/dff_clkout.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/test_gray.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/dff.py -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# copying cosimulation/icarus/test/tb_test.v -> build/bdist.linux-x86_64/egg/share/myhdl/cosimulation/icarus/test
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying myhdl.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying myhdl.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying myhdl.egg-info/dependency_links.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying myhdl.egg-info/top_level.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# zip_safe flag not set; analyzing archive contents...
# myhdl.__pycache__._Waiter.cpython-37: module MAY be using inspect.getsource
# myhdl.__pycache__._blackbox.cpython-37: module MAY be using inspect.trace
# myhdl.__pycache__._block.cpython-37: module MAY be using inspect.getsourcefile
# myhdl.__pycache__._block.cpython-37: module MAY be using inspect.stack
# myhdl.__pycache__._block.cpython-37: module MAY be using inspect.trace
# myhdl.__pycache__._extractHierarchy.cpython-37: module MAY be using inspect.getsourcefile
# myhdl.__pycache__._instance.cpython-37: module MAY be using inspect.stack
# myhdl.__pycache__._misc.cpython-37: module MAY be using inspect.getouterframes
# myhdl.__pycache__._util.cpython-37: module MAY be using inspect.getsource
# myhdl.__pycache__._util.cpython-37: module MAY be using inspect.getsourcefile
# myhdl.conversion.__pycache__._toVerilog.cpython-37: module MAY be using inspect.trace
# myhdl.conversion.__pycache__._toYosys.cpython-37: module MAY be using inspect.stack
# myhdl.conversion.__pycache__._toYosys.cpython-37: module MAY be using inspect.trace
# myhdl.conversion.__pycache__.ysmodule_ng.cpython-37: module MAY be using inspect.getouterframes
# creating 'dist/myhdl-0.11-py3.7.egg' and adding 'build/bdist.linux-x86_64/egg' to it
# removing 'build/bdist.linux-x86_64/egg' (and everything under it)
# Processing myhdl-0.11-py3.7.egg
# removing '/home/pyosys/.local/lib/python3.7/site-packages/myhdl-0.11-py3.7.egg' (and everything under it)
# creating /home/pyosys/.local/lib/python3.7/site-packages/myhdl-0.11-py3.7.egg
# Extracting myhdl-0.11-py3.7.egg to /home/pyosys/.local/lib/python3.7/site-packages
# myhdl 0.11 is already the active version in easy-install.pth
#
# Installed /home/pyosys/.local/lib/python3.7/site-packages/myhdl-0.11-py3.7.egg
# Processing dependencies for myhdl==0.11
# Finished processing dependencies for myhdl==0.11

# %% [markdown]
# Or you could explicitely set the module search path to the working branch:

# %%
import sys
sys.path.insert(0, "../../")
import myhdl
print(myhdl.__file__)
# Out:
# ../../myhdl/__init__.py

# %% [markdown]
# ## Updating/installing a package
#
# To install or update to a recent debian package:

# %%
! sudo apt-get update
# Out:
# Hit:2 http://deb.debian.org/debian buster InRelease
# Get:3 http://security.debian.org/debian-security buster/updates InRelease [65.4 kB]
# Get:4 http://deb.debian.org/debian buster-updates InRelease [51.9 kB]
# Get:1 https://section5.ch/debian buster InRelease [7086 B]
# Get:5 http://security.debian.org/debian-security buster/updates/main amd64 Packages [204 kB]
# Get:6 http://deb.debian.org/debian buster-updates/main amd64 Packages.diff/Index [3688 B]
# Get:7 http://deb.debian.org/debian buster-updates/main amd64 Packages 2020-06-04-2016.16.pdiff [1101 B]
# Get:8 http://deb.debian.org/debian buster-updates/main amd64 Packages 2020-06-07-1403.53.pdiff [439 B]
# Get:9 http://deb.debian.org/debian buster-updates/main amd64 Packages 2020-06-13-2000.26.pdiff [552 B]
# Get:9 http://deb.debian.org/debian buster-updates/main amd64 Packages 2020-06-13-2000.26.pdiff [552 B]
# Get:10 https://section5.ch/debian buster/non-free amd64 Packages [6240 B]
# Fetched 340 kB in 1s (332 kB/s)
# Reading package lists... Done

# %%
! sudo apt-get install yosys-ghdl yosys-techlibs yosys-pyosys
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# yosys-ghdl is already the newest version (0.9-testing-hpg).
# yosys-techlibs is already the newest version (0.9-testing-hpg).
# yosys-pyosys is already the newest version (0.9-testing-hpg).
# 0 upgraded, 0 newly installed, 0 to remove and 3 not upgraded.
